# %%
# %matplotlib widget
import rebound
zoom=8

sim = rebound.Simulation()
sim.add("10") #Sun 0
sim.add("599") #Jupyter 1

#Juypter Monde in Gelb (sichtbar bei Zoom 0.02)
sim.add("502", primary=sim.particles[1]) #Europa 2
sim.add("501", primary=sim.particles[1]) #Io 3
sim.add("504", primary=sim.particles[1]) #Callisto 4

#L4 Trojaner in Schwarz
sim.add("588") #5888 Achilles L4 5
sim.add("1437") #(1437) Diomedes L4 6
sim.add("15094") #15094 Polymele (1999 WB2) 7
sim.add("11351") #11351 Leucus (1997 TS25) 8
sim.add("21900") #21900 Orus (1999 VQ10) 9

#L5 Trojaner in Grau
sim.add("A906 UL") #617 Patroclus (A906 UL) 10
sim.add("884") #(884) Priamus 11
sim.add("1172") #(1172) Äneas 12
sim.add("1173") #(1173) Anchises 13


ob1 = rebound.OrbitPlot(sim, particles = [1, 5, 6, 7, 8, 9, 10, 11, 12, 13], xlim=(sim.particles[1].x-zoom, sim.particles[1].x+zoom), ylim=(sim.particles[1].y-zoom,sim.particles[1].y+zoom), orbit_style=None)
ob2 = rebound.OrbitPlot(sim, particles = [2,3,4], primary=1, show_primary=False, fig=ob1.fig, ax = ob1.ax)

ob1.particles.set_color(["yellow", "black","black","black","black","black", "grey", "grey", "grey", "grey"])
ob2.particles.set_color(["blue"])

w = sim.getWidget()
w
# Out:
# Searching NASA Horizons for '10'...
# Found: Sun (10)
# Searching NASA Horizons for '599'...
# Found: Jupiter (599)
# Searching NASA Horizons for '502'...
# Found: Europa (502)
# Searching NASA Horizons for '501'...
# Found: Io (501)
# Searching NASA Horizons for '504'...
# Found: Callisto (504)
# Searching NASA Horizons for '588'...
# Found: 588 Achilles (A906 DN)
# Searching NASA Horizons for '1437'...
# Found: 1437 Diomedes (1937 PB)
# Searching NASA Horizons for '15094'...
# Found: 15094 Polymele (1999 WB2)
# Searching NASA Horizons for '11351'...
# Found: 11351 Leucus (1997 TS25)
# Searching NASA Horizons for '21900'...
# Found: 21900 Orus (1999 VQ10)
# Searching NASA Horizons for 'A906 UL'...
# Found: 617 Patroclus (A906 UL)
# Searching NASA Horizons for '884'...
# Found: 884 Priamus (A917 SU)
# Searching NASA Horizons for '1172'...
# Found: 1172 Aneas (1930 UA)
# Searching NASA Horizons for '1173'...
# Found: 1173 Anchises (1930 UB)
# ...

# %%
fig = ob1.fig
for i in range(500):
    ob1.sim.integrate(sim.t+0.05)
    ob2.sim.integrate(sim.t+0.05)

    ob1.xlim = [sim.particles[1].x-zoom, sim.particles[1].x+zoom]
    ob1.ylim = [sim.particles[1].y-zoom, sim.particles[1].y+zoom]

    ob1.update()
    ob2.update()

    fig.canvas.draw()
    w
